# %% [markdown]
# <a href="https://colab.research.google.com/github/him863/2.-Investigating-Netflix-movies-and-Guest-stars-in-the-office/blob/main/prompt_eng_assgn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Question 1:
#
#  a. Craft a detailed prompt to generate subjective answers for questions of grade 10th Science in a structured way. The questions are for 2,3,4,5,6 marks and the prompt
# should be able to create solutions accordingly.

# %% [markdown]
# Ans :
#
# To generate subjective answers for 10th-grade Science questions of varying marks (2, 3, 4, 5, and 6 marks), the prompt should consider the following structure and elements:
#
# Question Stem: Briefly describe the question or the problem statement.
#
# Key Concepts: Identify the key concepts or topics involved in the question.
#
# Explanation: Provide a detailed explanation or solution, including relevant
# diagrams, formulas, or equations.
#
# Examples: Include examples or real-life scenarios to illustrate the concept.
#
# Conclusion: Summarize the answer and restate the key points.
#
#  provide 5 questions and solutions in structured manner covering different marks

# %% [markdown]
# b. What parameters did you keep in mind while crafting this prompt?

# %% [markdown]
#  Ans : 1. Clarity 2. Sturcture 3.Depth Understanding 4.Critical Thinking 5.Marking pattern

# %% [markdown]
# # Ques 3 :
#
# a. I asked GPT to write an essay in 100 words but it generated an essay in 90 words and sometimes less than that. Why exactly did that happen? Why was GPT not able to give me the essay in exactly 100 words even after prompting well?

# %% [markdown]
# Ans : There may be a few resons for it which are mentioned below:
#
# 1. Algorithmic Limitations
#
# 2. Prompt Ambiguity even after best possible efforts
#
# 3. Sampling Variability
#
# 4. Training Data Influence

# %% [markdown]
# b. ChatGPT is not that great in maths/reasoning (specifically higher grades), why so? What’s the fundamental reason behind it?

# %% [markdown]
# Ans -
#
# There may be a couple of resons for it, mentioned as below:
#
# 1. Training Data (generalised traing rather than specific to maths)
#
# 2. Architecture (Transformer based more suitable for natural language text)
#
# 3. Complexity of problem.

# %% [markdown]
# # Ques 2 -
#
# a. Craft a prompt to generate an image of a 13-year-old kid in the art style, orientation and size of the image shared below. You can use any free image-generation software to perform this task.

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-86d2d041-ecae-49a5-b484-62fdd890bdec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86d2d041-ecae-49a5-b484-62fdd890bdec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('Screenshot 2024-05-08 at 6.22.41 PM.png')

# %% [markdown]
#  b) What parameters did you keep in mind while creating this image? (the 13 year old boy image)

# %% [markdown]
# Ans -
#
# 1. Art Style
# 2. Orientation
# 3. Age were key paramteres were aligned based on given image **bold text**
